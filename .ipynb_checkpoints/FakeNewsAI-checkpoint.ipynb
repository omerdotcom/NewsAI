# %%
import pandas as pd

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

# %%
fake['label'] = 0
true['label'] = 1

# %%
df = pd.concat([fake,true]).sample(frac=1).reset_index(drop=True)
print(df)
# Out:
#                                                    title  \
# 0      CAN’T STOP LAUGHING! One Of “Bernie’s Basement...
# 1      Critics accuse UK government of not taking Bre...
# 2       May calls for Brexit talks progress at EU summit
# 3      Britain to submit 'Brexit bill' proposal befor...
# 4       Fox News Host Jesse Watters Takes ‘Vacation’ ...
# ...                                                  ...
# 44893  Mexico's Pena Nieto says agreed Trump meeting ...
# 44894   DESPERATE Senate Republicans Just Dropped Pro...
# 44895  REVEALING GRAPH: TRUMP Setting Records In Hist...
# 44896  CNN CUTS FEED Of CONGRESSMAN As Soon As He Spe...
# 44897  Republicans propose to delay, pause Obamacare ...
#
#                                                     text       subject  \
# 0      Can t Stop Laughing! ??Bernie s #BasementDwell...      politics
# 1      LONDON (Reuters) - Pro-European campaigners ac...     worldnews
# 2      BRUSSELS (Reuters) - Prime Minister Theresa Ma...     worldnews
# 3      LONDON (Reuters) - Britain will submit proposa...     worldnews
# 4      Remember when Bill O Reilly took a vacation af...          News
# ...                                                  ...           ...
# 44893  MEXICO CITY (Reuters) - Mexican President Enri...  politicsNews
# 44894  No matter how much they don t want to admit it...          News
# 44895  DON T LISTEN TO THE MAIN STREAM MEDIA BIAS!Whi...      politics
# 44896                                                         politics
# 44897  WASHINGTON (Reuters) - U.S. House Republicans ...  politicsNews
#
#                      date  label
# 0             Oct 1, 2016      0
# 1      December 21, 2017       1
# 2       October 19, 2017       1
# 3      November 19, 2017       1
# 4          April 27, 2017      0
# ...                   ...    ...
# 44893   November 9, 2016       1
# 44894     October 4, 2016      0
# 44895         Jun 9, 2016      0
# 44896         Mar 7, 2017      0
# 44897  December 12, 2017       1
#
# [44898 rows x 5 columns]

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno -2] Name or
# [nltk_data]     service not known>
# False

# %%
stop = set(stopwords.words('english'))
def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]','',text)
    text = text.lower()
    return " ".join([w for w in text.split() if w not in stop])
df['text'] = df['text'].apply(clean_text)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df['text'],df['label'],test_size=0.2,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=5000)
x_train_vec = vectorizer.fit_transform(x_train)
x_test_vec = vectorizer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, accuracy_score
y_pred = model.predict(x_test_vec)
print('accuracy: ',accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy:  0.989086859688196
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4725
#            1       0.99      0.99      0.99      4255
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues',xticklabels=['Fake','Real'],yticklabels=['Fake','Real'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#A function to clean entered text
def predict_news(text):
    clean = clean_text(text)
    vec = vectorizer.transform([clean])
    pred = model.predict(vec)[0]
    proba = model.predict_proba(vec)[0]
    label = 'REAL' if pred == 1 else 'FAKE'
    confidence = round(max(proba)*100,2)
    return f'{label}, confidence = {confidence}'

# %%
print(predict_news(''))
# Out:
# FAKE, confidence = 99.75
