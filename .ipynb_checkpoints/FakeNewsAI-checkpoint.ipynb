# %%
import pandas as pd

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

# %%
fake['label'] = 0
true['label'] = 1

# %%
df = pd.concat([fake,true]).sample(frac=1).reset_index(drop=True)
print(df)
# Out:
#                                                    title  \
# 0       Trump-Touted Wisconsin Deal Forces Taxpayers ...
# 1      Exclusive: Democratic Party slams GOP candidat...
# 2      Silicon Valley mocks Trump over his tech bubbl...
# 3      Highlights: The Trump presidency on March 13 a...
# 4      Ex-Trump campaign chief Manafort wants probe o...
# ...                                                  ...
# 44893   Richard Dreyfuss Uses GMA Interview To Troll ...
# 44894   Republicans PANICKING After Federal Judge Shu...
# 44895  U.S. says ban-the-bomb Nobel winner won't make...
# 44896  China calls for restraint over North Korea ten...
# 44897  U.S. says countries should suspend providing w...
#
#                                                     text       subject  \
# 0      Donald Trump is so desperate to take credit fo...          News
# 1      NEW YORK (Reuters) - The Democratic Party rele...  politicsNews
# 2      SAN FRANCISCO (Reuters) - Republican president...  politicsNews
# 3      (Reuters) - Highlights of the day for U.S. Pre...  politicsNews
# 4      WASHINGTON (Reuters) - Paul Manafort, Presiden...  politicsNews
# ...                                                  ...           ...
# 44893  Legendary actor Richard Dreyfuss has been hitt...          News
# 44894  The Trump campaign is self destructing. If thi...          News
# 44895  OSLO (Reuters) - The Nobel Peace Prize winner ...     worldnews
# 44896  BEIJING (Reuters) - China said on Monday that ...     worldnews
# 44897  UNITED NATIONS (Reuters) - U.S. Ambassador to ...     worldnews
#
#                       date  label
# 0            July 27, 2017      0
# 1       February 28, 2016       1
# 2            May 18, 2016       1
# 3          March 13, 2017       1
# 4      September 21, 2017       1
# ...                    ...    ...
# 44893     February 3, 2016      0
# 44894     October 10, 2016      0
# 44895   November 30, 2017       1
# 44896  September 25, 2017       1
# 44897  September 28, 2017       1
#
# [44898 rows x 5 columns]

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/omer/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop = set(stopwords.words('english'))
def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]','',text)
    text = text.lower()
    return " ".join([w for w in text.split() if w not in stop])
df['text'] = df['text'].apply(clean_text)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df['text'],df['label'],test_size=0.2,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=5000)
x_train_vec = vectorizer.fit_transform(x_train)
x_test_vec = vectorizer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, accuracy_score
y_pred = model.predict(x_test_vec)
print('accuracy: ',accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy:  0.9874164810690423
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      4713
#            1       0.98      0.99      0.99      4267
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980
